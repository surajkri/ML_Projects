# %%
import pandas as pd
import matplotlib as mlt
import numpy as np
import seaborn as snr

# %%
data=pd.read_csv("/content/sample_data/Persistent data set-2.csv")

# %%
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      320 non-null    object
#  1   Value     320 non-null    int64
#  2   nifty-50  320 non-null    int64
#  3   Sensex    320 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 10.1+ KB
#        Date  Value  nifty-50    Sensex
# 0  1/3/2022   4872     17625  59183.22
# 1  1/4/2022   4836     17805  59855.93
# 2  1/5/2022   4678     17925  60223.15
# 3  1/6/2022   4534     17745  59601.84
# 4  1/7/2022   4545     17812  59744.65

# %%
d=data.iloc[0:300].plot(figsize=(8,3), title="Persistent")
d.set_xlabel("Day")
d.set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
data.iloc[0:21]['Value'].diff().plot(kind="bar")      # histogram

# %%
data.iloc[0:9].plot(figsize=(8,8),kind='bar')

# %%
piedata=data.drop(['Date'],axis=1)

# %%
data.dtypes
# data['Date']=pd.to_datetime(data['Date'])
# Out:
# Date         object
# Value         int64
# nifty-50      int64
# Sensex      float64
# dtype: object

# %%
piedata.plot.pie(figsize=(10,10),fontsize=15,autopct='%.2f',subplots=True) # need to explain
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8671dd0340>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8671d7f2e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8671da5520>],
#       dtype=object)

# %%
piedata.iloc[0:3].plot.pie(subplots=True)      #need to explain
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f866fdbca60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f86701ebf70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f86701430d0>],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      320 non-null    object
#  1   Value     320 non-null    int64
#  2   nifty-50  320 non-null    int64
#  3   Sensex    320 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 10.1+ KB

# %%
predata=data.drop(['Date'],axis=1)

# %%
x=predata[['nifty-50','Sensex']]
y=predata[['Value']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (256, 2)

# %%
y_train.shape
# Out:
# (256, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
lregression=LinearRegression()
dregression=DecisionTreeRegressor()

# %%
lregression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
dregression.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
lregression.score(x,y)
# Out:
# -4669.646822738171

# %%
dregression.score(x,y)
# Out:
# 0.6711179229711504

# %% [markdown]
# #26/12/2022 data of sensex and nifty-50

# %%
lregression.predict([[17993,60495.27]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4034.38642659]])

# %%
dregression.predict([[17993,60495.27]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([3621.])
